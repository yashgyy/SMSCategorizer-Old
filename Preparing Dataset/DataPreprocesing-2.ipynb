# %%
import pandas as pd

# %%
PD=pd.read_csv('spam.csv')

# %%
PD=PD[PD['v1']=='spam']

# %%
XY1=PD.loc[100:600]

# %%
XY1
# Out:
#        v1                                                 v2 Unnamed: 2  \
# 113  spam  GENT! We are trying to contact you. Last weeke...        NaN
# 116  spam  You are a winner U have been specially selecte...        NaN
# 119  spam  PRIVATE! Your 2004 Account Statement for 07742...        NaN
# 120  spam  URGENT! Your Mobile No. was awarded 2000 Bonus...        NaN
# 122  spam  Todays Voda numbers ending 7548 are selected t...        NaN
# 133  spam  Sunshine Quiz Wkly Q! Win a top Sony DVD playe...        NaN
# 134  spam  Want 2 get laid tonight? Want real Dogging loc...        NaN
# 138  spam  You'll not rcv any more msgs from the chat svc...        NaN
# 146  spam  FreeMsg Why haven't you replied to my text? I'...        NaN
# 158  spam  Customer service annoncement. You have a New Y...        NaN
# 159  spam  You are a winner U have been specially selecte...        NaN
# 163  spam  -PLS STOP bootydelious (32/F) is inviting you ...        NaN
# ...

# %%
XY1.drop('Unnamed: 4',axis=1,inplace=True)
# Out:
# C:\Users\yashg\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
XY1.drop(['Unnamed: 2','Unnamed: 3'],axis=1,inplace=True)
# Out:
# C:\Users\yashg\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
XY1
# Out:
#        v1                                                 v2
# 113  spam  GENT! We are trying to contact you. Last weeke...
# 116  spam  You are a winner U have been specially selecte...
# 119  spam  PRIVATE! Your 2004 Account Statement for 07742...
# 120  spam  URGENT! Your Mobile No. was awarded 2000 Bonus...
# 122  spam  Todays Voda numbers ending 7548 are selected t...
# 133  spam  Sunshine Quiz Wkly Q! Win a top Sony DVD playe...
# 134  spam  Want 2 get laid tonight? Want real Dogging loc...
# 138  spam  You'll not rcv any more msgs from the chat svc...
# 146  spam  FreeMsg Why haven't you replied to my text? I'...
# 158  spam  Customer service annoncement. You have a New Y...
# 159  spam  You are a winner U have been specially selecte...
# 163  spam  -PLS STOP bootydelious (32/F) is inviting you ...
# 164  spam  BangBabes Ur order is on the way. U SHOULD rec...
# 166  spam  URGENT! We are trying to contact you. Last wee...
# ...

# %%
XY1.rename(columns={'v1':'labels','v2':'Body'},inplace=True)
# Out:
# C:\Users\yashg\Anaconda3\lib\site-packages\pandas\core\frame.py:2746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   **kwargs)

# %%
XY1
# Out:
#     labels                                               Body
# 113   spam  GENT! We are trying to contact you. Last weeke...
# 116   spam  You are a winner U have been specially selecte...
# 119   spam  PRIVATE! Your 2004 Account Statement for 07742...
# 120   spam  URGENT! Your Mobile No. was awarded 2000 Bonus...
# 122   spam  Todays Voda numbers ending 7548 are selected t...
# 133   spam  Sunshine Quiz Wkly Q! Win a top Sony DVD playe...
# 134   spam  Want 2 get laid tonight? Want real Dogging loc...
# 138   spam  You'll not rcv any more msgs from the chat svc...
# 146   spam  FreeMsg Why haven't you replied to my text? I'...
# 158   spam  Customer service annoncement. You have a New Y...
# 159   spam  You are a winner U have been specially selecte...
# 163   spam  -PLS STOP bootydelious (32/F) is inviting you ...
# 164   spam  BangBabes Ur order is on the way. U SHOULD rec...
# 166   spam  URGENT! We are trying to contact you. Last wee...
# ...

# %%
XY1.to_csv('Temp.csv',index=True)

# %%
Abc=pd.read_csv('Temp.csv')

# %%
XY1.reset_index(inplace=True)

# %%
XY1.drop('index',axis=1,inplace=True)
# Out:
# C:\Users\yashg\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
XY1
# Out:
#    labels                                               Body
# 0    spam  GENT! We are trying to contact you. Last weeke...
# 1    spam  You are a winner U have been specially selecte...
# 2    spam  PRIVATE! Your 2004 Account Statement for 07742...
# 3    spam  URGENT! Your Mobile No. was awarded 2000 Bonus...
# 4    spam  Todays Voda numbers ending 7548 are selected t...
# 5    spam  Sunshine Quiz Wkly Q! Win a top Sony DVD playe...
# 6    spam  Want 2 get laid tonight? Want real Dogging loc...
# 7    spam  You'll not rcv any more msgs from the chat svc...
# 8    spam  FreeMsg Why haven't you replied to my text? I'...
# 9    spam  Customer service annoncement. You have a New Y...
# 10   spam  You are a winner U have been specially selecte...
# 11   spam  -PLS STOP bootydelious (32/F) is inviting you ...
# 12   spam  BangBabes Ur order is on the way. U SHOULD rec...
# 13   spam  URGENT! We are trying to contact you. Last wee...
# ...

# %%
XY1.to_csv('Temp.csv',index=False)

# %%
ABC=pd.read_csv('Temp.csv')

# %%
ABD=pd.read_csv('File14.csv')

# %%
ABD.drop('Unnamed: 0',axis=1,inplace=True)

# %%
ABD
# Out:
#                                                   Body    labels
# 0                                Bugis oso near wat...  Personal
# 1    Go until jurong point, crazy.. Available only ...  Personal
# 2       I dunno until when... Lets go learn pilates...  Personal
# 3    Den only weekdays got special price... Haiz......  Personal
# 4                               Meet after lunch la...  Personal
# 5    m walking in citylink now  faster come down......  Personal
# 6    5 nights...We nt staying at port step liao...T...  Personal
# 7    Hey pple...$700 or $900 for 5 nights...Excelle...  Personal
# 8    Yun ah.the ubi one say if  wan call by tomorro...  Personal
# 9                    Hey tmr maybe can meet you at yck  Personal
# 10            Oh...i asked for fun. Haha...take care.   Personal
# 11   We are supposed to meet to discuss abt our tri...  Personal
# 12                             t finish my film yet...  Personal
# ...

# %%
Labels=[ABD,XY1]
LL=pd.concat(Labels)

# %%
LL.reset_index(inplace=True)

# %%
LL.drop('index',inplace=True,axis=1)

# %%
LL
# Out:
#                                                   Body    labels
# 0                                Bugis oso near wat...  Personal
# 1    Go until jurong point, crazy.. Available only ...  Personal
# 2       I dunno until when... Lets go learn pilates...  Personal
# 3    Den only weekdays got special price... Haiz......  Personal
# 4                               Meet after lunch la...  Personal
# 5    m walking in citylink now  faster come down......  Personal
# 6    5 nights...We nt staying at port step liao...T...  Personal
# 7    Hey pple...$700 or $900 for 5 nights...Excelle...  Personal
# 8    Yun ah.the ubi one say if  wan call by tomorro...  Personal
# 9                    Hey tmr maybe can meet you at yck  Personal
# 10            Oh...i asked for fun. Haha...take care.   Personal
# 11   We are supposed to meet to discuss abt our tri...  Personal
# 12                             t finish my film yet...  Personal
# ...

# %%
LL['labels'].value_counts()
# Out:
# Personal    408
# service      76
# spam         57
# online       29
# bank         21
# cabs         16
# food         10
# reminder      7
# others        6
# Name: labels, dtype: int64

# %%
LL.to_csv('File16.csv',index=False)
