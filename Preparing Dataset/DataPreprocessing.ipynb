# %%
import pandas as pd

# %%
import numpy as np

# %%
Data1=pd.read_json('smsCorpus_en_2015.03.09_all.json')

# %%
Data1
# Out:
#                                                   smsCorpus
# @date                                            2015.03.09
# @version                                                1.2
# message   [{'source': {'userProfile': {'gender': {'$': '...

# %%
for x in D
# Out:
# smsCorpus    [{'source': {'userProfile': {'gender': {'$': '...
# Name: message, dtype: object

# %%
print(Data1.lo
# Out:
# smsCorpus    [{'source': {'userProfile': {'gender': {'$': '...
# Name: message, dtype: object

# %%
Y=Data1.loc['message'][0]

# %%
List1=[]
i=0
for x in Y:
    List1.append(x['text'])
    i=i+1
    if(i>200):
        break

# %%
List2=[]
for X in List1:
    List2.append(X['$'])

# %%
List2
# Out:
# ['Bugis oso near wat...',
#  'Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...',
#  'I dunno until when... Lets go learn pilates...',
#  'Den only weekdays got special price... Haiz... Cant eat liao... Cut nails oso muz wait until i finish drivin wat, lunch still muz eat wat...',
#  'Meet after lunch la...',
#  'm walking in citylink now ü faster come down... Me very hungry...',
#  '5 nights...We nt staying at port step liao...Too ex',
#  'Hey pple...$700 or $900 for 5 nights...Excellent location wif breakfast hamper!!!',
#  'Yun ah.the ubi one say if ü wan call by tomorrow.call 67441233 look for irene.ere only got bus8,22,65,61,66,382. Ubi cres,ubi tech park.6ph for 1st 5wkg days.èn',
#  'Hey tmr maybe can meet you at yck',
#  'Oh...i asked for fun. Haha...take care. ü',
#  'We are supposed to meet to discuss abt our trip... Thought xuhui told you? In the afternoon. Thought we can go for lesson after that',
# ...

# %%
with open("Peronal.txt","w") as F:
    for X in List2:
        print(X)
# Out:
# Bugis oso near wat...
# Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# I dunno until when... Lets go learn pilates...
# Den only weekdays got special price... Haiz... Cant eat liao... Cut nails oso muz wait until i finish drivin wat, lunch still muz eat wat...
# Meet after lunch la...
# m walking in citylink now ü faster come down... Me very hungry...
# 5 nights...We nt staying at port step liao...Too ex
# Hey pple...$700 or $900 for 5 nights...Excellent location wif breakfast hamper!!!
# Yun ah.the ubi one say if ü wan call by tomorrow.call 67441233 look for irene.ere only got bus8,22,65,61,66,382. Ubi cres,ubi tech park.6ph for 1st 5wkg days.èn
# Hey tmr maybe can meet you at yck
# Oh...i asked for fun. Haha...take care. ü
# We are supposed to meet to discuss abt our trip... Thought xuhui told you? In the afternoon. Thought we can go for lesson after that
# t finish my film yet...
# ...

# %%
with open("Peronal.txt","w") as F:
    for X in List2:
        F.write(str(X)+"!Personal"+'\n')

# %%
pd.read_csv('Peronal.txt',delimiter='<')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens (pandas\_libs\parsers.c:14858)()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype (pandas\_libs\parsers.c:17119)()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert (pandas\_libs\parsers.c:17347)()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8 (pandas\_libs\parsers.c:23041)()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xfc in position 51: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-52-c722ee8ccf76> in <module>()
# ----> 1 pd.read_csv('Peronal.txt',delimiter='<')
#
# ...

# %%
np.array(X)
# Out:
# array('m on da bus going home...',
#       dtype='<U25')

# %%
X
# Out:
# 'm on da bus going home...'

# %%
L=np.array(List2)

# %%
LL=pd.DataFrame(L)

# %%
LL.columns
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %%
LL
# Out:
#                                                      0
# 0                                Bugis oso near wat...
# 1    Go until jurong point, crazy.. Available only ...
# 2       I dunno until when... Lets go learn pilates...
# 3    Den only weekdays got special price... Haiz......
# 4                               Meet after lunch la...
# 5    m walking in citylink now ü faster come down.....
# 6    5 nights...We nt staying at port step liao...T...
# 7    Hey pple...$700 or $900 for 5 nights...Excelle...
# 8    Yun ah.the ubi one say if ü wan call by tomorr...
# 9                    Hey tmr maybe can meet you at yck
# 10           Oh...i asked for fun. Haha...take care. ü
# 11   We are supposed to meet to discuss abt our tri...
# 12                             t finish my film yet...
# 13                   m having dinner with my cousin...
# 14                          Oh... Kay... On sat right?
# 15                     I need... Coz i never go before
# ...

# %%
LLL=LL.rename(columns={0:'Body'})

# %%
LLL['labels']=LLL.apply(lambda x:Personal')

# %%
LLL.fillna('Personal',axis=1)
# Out:
#                                                   Body    labels
# 0                                Bugis oso near wat...  Personal
# 1    Go until jurong point, crazy.. Available only ...  Personal
# 2       I dunno until when... Lets go learn pilates...  Personal
# 3    Den only weekdays got special price... Haiz......  Personal
# 4                               Meet after lunch la...  Personal
# 5    m walking in citylink now ü faster come down.....  Personal
# 6    5 nights...We nt staying at port step liao...T...  Personal
# 7    Hey pple...$700 or $900 for 5 nights...Excelle...  Personal
# 8    Yun ah.the ubi one say if ü wan call by tomorr...  Personal
# 9                    Hey tmr maybe can meet you at yck  Personal
# 10           Oh...i asked for fun. Haha...take care. ü  Personal
# 11   We are supposed to meet to discuss abt our tri...  Personal
# 12                             t finish my film yet...  Personal
# ...

# %%
LLL.to_csv("File.csv",index=False)

# %%
XX=pd.read_csv('File.csv')

# %%
XX=XX.fillna('Personal',axis=1)

# %%
XX.to_csv('File23.csv',index=False)

# %%
pd.read_csv('File23.csv')
# Out:
#                                                   Body    labels
# 0                                Bugis oso near wat...  Personal
# 1    Go until jurong point, crazy.. Available only ...  Personal
# 2       I dunno until when... Lets go learn pilates...  Personal
# 3    Den only weekdays got special price... Haiz......  Personal
# 4                               Meet after lunch la...  Personal
# 5    m walking in citylink now  faster come down......  Personal
# 6    5 nights...We nt staying at port step liao...T...  Personal
# 7    Hey pple...$700 or $900 for 5 nights...Excelle...  Personal
# 8    Yun ah.the ubi one say if  wan call by tomorro...  Personal
# 9                    Hey tmr maybe can meet you at yck  Personal
# 10            Oh...i asked for fun. Haha...take care.   Personal
# 11   We are supposed to meet to discuss abt our tri...  Personal
# 12                             t finish my film yet...  Personal
# ...

# %%
XXXX=pd.read_csv('spam.csv')
XXXX
# Out:
#        v1                                                 v2 Unnamed: 2  \
# 0     ham  Go until jurong point, crazy.. Available only ...        NaN
# 1     ham                      Ok lar... Joking wif u oni...        NaN
# 2    spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3     ham  U dun say so early hor... U c already then say...        NaN
# 4     ham  Nah I don't think he goes to usf, he lives aro...        NaN
# 5    spam  FreeMsg Hey there darling it's been 3 week's n...        NaN
# 6     ham  Even my brother is not like to speak with me. ...        NaN
# 7     ham  As per your request 'Melle Melle (Oru Minnamin...        NaN
# 8    spam  WINNER!! As a valued network customer you have...        NaN
# 9    spam  Had your mobile 11 months or more? U R entitle...        NaN
# 10    ham  I'm gonna be home soon and i don't want to tal...        NaN
# 11   spam  SIX chances to win CASH! From 100 to 20,000 po...        NaN
# ...

# %%
XXXX['Labels']=XXXX['v1'].map({'ham':'Personal','spam':'spam'})

# %%
XXXX.drop('v1',axis=1)
# Out:
#                                                     v2 Unnamed: 2 Unnamed: 3  \
# 0    Go until jurong point, crazy.. Available only ...        NaN        NaN
# 1                        Ok lar... Joking wif u oni...        NaN        NaN
# 2    Free entry in 2 a wkly comp to win FA Cup fina...        NaN        NaN
# 3    U dun say so early hor... U c already then say...        NaN        NaN
# 4    Nah I don't think he goes to usf, he lives aro...        NaN        NaN
# 5    FreeMsg Hey there darling it's been 3 week's n...        NaN        NaN
# 6    Even my brother is not like to speak with me. ...        NaN        NaN
# 7    As per your request 'Melle Melle (Oru Minnamin...        NaN        NaN
# 8    WINNER!! As a valued network customer you have...        NaN        NaN
# 9    Had your mobile 11 months or more? U R entitle...        NaN        NaN
# 10   I'm gonna be home soon and i don't want to tal...        NaN        NaN
# ...

# %%
XXXX.columns
# Out:
# Index(['v1', 'v2', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Labels'], dtype='object')

# %%
XXXX1=XXXX.drop(['Unnamed: 2','Unnamed: 3','Unnamed: 4'],axis=1)

# %%
XXXX.drop('v1',axis=1)
# Out:
#                                                     v2 Unnamed: 2 Unnamed: 3  \
# 0    Go until jurong point, crazy.. Available only ...        NaN        NaN
# 1                        Ok lar... Joking wif u oni...        NaN        NaN
# 2    Free entry in 2 a wkly comp to win FA Cup fina...        NaN        NaN
# 3    U dun say so early hor... U c already then say...        NaN        NaN
# 4    Nah I don't think he goes to usf, he lives aro...        NaN        NaN
# 5    FreeMsg Hey there darling it's been 3 week's n...        NaN        NaN
# 6    Even my brother is not like to speak with me. ...        NaN        NaN
# 7    As per your request 'Melle Melle (Oru Minnamin...        NaN        NaN
# 8    WINNER!! As a valued network customer you have...        NaN        NaN
# 9    Had your mobile 11 months or more? U R entitle...        NaN        NaN
# 10   I'm gonna be home soon and i don't want to tal...        NaN        NaN
# ...

# %%
XXXX1
# Out:
#        v1                                                 v2    Labels
# 0     ham  Go until jurong point, crazy.. Available only ...  Personal
# 1     ham                      Ok lar... Joking wif u oni...  Personal
# 2    spam  Free entry in 2 a wkly comp to win FA Cup fina...      spam
# 3     ham  U dun say so early hor... U c already then say...  Personal
# 4     ham  Nah I don't think he goes to usf, he lives aro...  Personal
# 5    spam  FreeMsg Hey there darling it's been 3 week's n...      spam
# 6     ham  Even my brother is not like to speak with me. ...  Personal
# 7     ham  As per your request 'Melle Melle (Oru Minnamin...  Personal
# 8    spam  WINNER!! As a valued network customer you have...      spam
# 9    spam  Had your mobile 11 months or more? U R entitle...      spam
# 10    ham  I'm gonna be home soon and i don't want to tal...  Personal
# 11   spam  SIX chances to win CASH! From 100 to 20,000 po...      spam
# ...

# %%
XXXX1.drop('v1',axis=1)
# Out:
#                                                     v2    Labels
# 0    Go until jurong point, crazy.. Available only ...  Personal
# 1                        Ok lar... Joking wif u oni...  Personal
# 2    Free entry in 2 a wkly comp to win FA Cup fina...      spam
# 3    U dun say so early hor... U c already then say...  Personal
# 4    Nah I don't think he goes to usf, he lives aro...  Personal
# 5    FreeMsg Hey there darling it's been 3 week's n...      spam
# 6    Even my brother is not like to speak with me. ...  Personal
# 7    As per your request 'Melle Melle (Oru Minnamin...  Personal
# 8    WINNER!! As a valued network customer you have...      spam
# 9    Had your mobile 11 months or more? U R entitle...      spam
# 10   I'm gonna be home soon and i don't want to tal...  Personal
# 11   SIX chances to win CASH! From 100 to 20,000 po...      spam
# 12   URGENT! You have won a 1 week FREE membership ...      spam
# ...

# %%
XXXX1.to_csv('Tyty.csv',index=False)

# %%
XXXX1
# Out:
#        v1                                                 v2    Labels
# 0     ham  Go until jurong point, crazy.. Available only ...  Personal
# 1     ham                      Ok lar... Joking wif u oni...  Personal
# 2    spam  Free entry in 2 a wkly comp to win FA Cup fina...      spam
# 3     ham  U dun say so early hor... U c already then say...  Personal
# 4     ham  Nah I don't think he goes to usf, he lives aro...  Personal
# 5    spam  FreeMsg Hey there darling it's been 3 week's n...      spam
# 6     ham  Even my brother is not like to speak with me. ...  Personal
# 7     ham  As per your request 'Melle Melle (Oru Minnamin...  Personal
# 8    spam  WINNER!! As a valued network customer you have...      spam
# 9    spam  Had your mobile 11 months or more? U R entitle...      spam
# 10    ham  I'm gonna be home soon and i don't want to tal...  Personal
# 11   spam  SIX chances to win CASH! From 100 to 20,000 po...      spam
# ...

# %%
pd.read_csv('Tyty.csv')
# Out:
#        v1                                                 v2    Labels
# 0     ham  Go until jurong point, crazy.. Available only ...  Personal
# 1     ham                      Ok lar... Joking wif u oni...  Personal
# 2    spam  Free entry in 2 a wkly comp to win FA Cup fina...      spam
# 3     ham  U dun say so early hor... U c already then say...  Personal
# 4     ham  Nah I don't think he goes to usf, he lives aro...  Personal
# 5    spam  FreeMsg Hey there darling it's been 3 week's n...      spam
# 6     ham  Even my brother is not like to speak with me. ...  Personal
# 7     ham  As per your request 'Melle Melle (Oru Minnamin...  Personal
# 8    spam  WINNER!! As a valued network customer you have...      spam
# 9    spam  Had your mobile 11 months or more? U R entitle...      spam
# 10    ham  I'm gonna be home soon and i don't want to tal...  Personal
# 11   spam  SIX chances to win CASH! From 100 to 20,000 po...      spam
# ...

# %%
LLL
# Out:
#                                                   Body labels
# 0                                Bugis oso near wat...    NaN
# 1    Go until jurong point, crazy.. Available only ...    NaN
# 2       I dunno until when... Lets go learn pilates...    NaN
# 3    Den only weekdays got special price... Haiz......    NaN
# 4                               Meet after lunch la...    NaN
# 5    m walking in citylink now ü faster come down.....    NaN
# 6    5 nights...We nt staying at port step liao...T...    NaN
# 7    Hey pple...$700 or $900 for 5 nights...Excelle...    NaN
# 8    Yun ah.the ubi one say if ü wan call by tomorr...    NaN
# 9                    Hey tmr maybe can meet you at yck    NaN
# 10           Oh...i asked for fun. Haha...take care. ü    NaN
# 11   We are supposed to meet to discuss abt our tri...    NaN
# 12                             t finish my film yet...    NaN
# 13                   m having dinner with my cousin...    NaN
# ...

# %%
A1=pd.read_csv('File23.csv')

# %%
A1
# Out:
#                                                   Body    labels
# 0                                Bugis oso near wat...  Personal
# 1    Go until jurong point, crazy.. Available only ...  Personal
# 2       I dunno until when... Lets go learn pilates...  Personal
# 3    Den only weekdays got special price... Haiz......  Personal
# 4                               Meet after lunch la...  Personal
# 5    m walking in citylink now  faster come down......  Personal
# 6    5 nights...We nt staying at port step liao...T...  Personal
# 7    Hey pple...$700 or $900 for 5 nights...Excelle...  Personal
# 8    Yun ah.the ubi one say if  wan call by tomorro...  Personal
# 9                    Hey tmr maybe can meet you at yck  Personal
# 10            Oh...i asked for fun. Haha...take care.   Personal
# 11   We are supposed to meet to discuss abt our tri...  Personal
# 12                             t finish my film yet...  Personal
# ...

# %%
A2=pd.read_csv('Tyty.csv')

# %%
A2
# Out:
#        v1                                                 v2    Labels
# 0     ham  Go until jurong point, crazy.. Available only ...  Personal
# 1     ham                      Ok lar... Joking wif u oni...  Personal
# 2    spam  Free entry in 2 a wkly comp to win FA Cup fina...      spam
# 3     ham  U dun say so early hor... U c already then say...  Personal
# 4     ham  Nah I don't think he goes to usf, he lives aro...  Personal
# 5    spam  FreeMsg Hey there darling it's been 3 week's n...      spam
# 6     ham  Even my brother is not like to speak with me. ...  Personal
# 7     ham  As per your request 'Melle Melle (Oru Minnamin...  Personal
# 8    spam  WINNER!! As a valued network customer you have...      spam
# 9    spam  Had your mobile 11 months or more? U R entitle...      spam
# 10    ham  I'm gonna be home soon and i don't want to tal...  Personal
# 11   spam  SIX chances to win CASH! From 100 to 20,000 po...      spam
# ...

# %%
A2.drop('v1',axis=1)
# Out:
#                                                     v2    Labels
# 0    Go until jurong point, crazy.. Available only ...  Personal
# 1                        Ok lar... Joking wif u oni...  Personal
# 2    Free entry in 2 a wkly comp to win FA Cup fina...      spam
# 3    U dun say so early hor... U c already then say...  Personal
# 4    Nah I don't think he goes to usf, he lives aro...  Personal
# 5    FreeMsg Hey there darling it's been 3 week's n...      spam
# 6    Even my brother is not like to speak with me. ...  Personal
# 7    As per your request 'Melle Melle (Oru Minnamin...  Personal
# 8    WINNER!! As a valued network customer you have...      spam
# 9    Had your mobile 11 months or more? U R entitle...      spam
# 10   I'm gonna be home soon and i don't want to tal...  Personal
# 11   SIX chances to win CASH! From 100 to 20,000 po...      spam
# 12   URGENT! You have won a 1 week FREE membership ...      spam
# ...

# %%
A2.rename(columns={'v2':'Body','Labels':'labels'})
# Out:
#        v1                                               Body    labels
# 0     ham  Go until jurong point, crazy.. Available only ...  Personal
# 1     ham                      Ok lar... Joking wif u oni...  Personal
# 2    spam  Free entry in 2 a wkly comp to win FA Cup fina...      spam
# 3     ham  U dun say so early hor... U c already then say...  Personal
# 4     ham  Nah I don't think he goes to usf, he lives aro...  Personal
# 5    spam  FreeMsg Hey there darling it's been 3 week's n...      spam
# 6     ham  Even my brother is not like to speak with me. ...  Personal
# 7     ham  As per your request 'Melle Melle (Oru Minnamin...  Personal
# 8    spam  WINNER!! As a valued network customer you have...      spam
# 9    spam  Had your mobile 11 months or more? U R entitle...      spam
# 10    ham  I'm gonna be home soon and i don't want to tal...  Personal
# 11   spam  SIX chances to win CASH! From 100 to 20,000 po...      spam
# ...

# %%
A1
# Out:
#                                                   Body    labels
# 0                                Bugis oso near wat...  Personal
# 1    Go until jurong point, crazy.. Available only ...  Personal
# 2       I dunno until when... Lets go learn pilates...  Personal
# 3    Den only weekdays got special price... Haiz......  Personal
# 4                               Meet after lunch la...  Personal
# 5    m walking in citylink now  faster come down......  Personal
# 6    5 nights...We nt staying at port step liao...T...  Personal
# 7    Hey pple...$700 or $900 for 5 nights...Excelle...  Personal
# 8    Yun ah.the ubi one say if  wan call by tomorro...  Personal
# 9                    Hey tmr maybe can meet you at yck  Personal
# 10            Oh...i asked for fun. Haha...take care.   Personal
# 11   We are supposed to meet to discuss abt our tri...  Personal
# 12                             t finish my film yet...  Personal
# ...

# %%
frames=[A1,A2]
A1
# Out:
#        v1                                                 v2    Labels
# 0     ham  Go until jurong point, crazy.. Available only ...  Personal
# 1     ham                      Ok lar... Joking wif u oni...  Personal
# 2    spam  Free entry in 2 a wkly comp to win FA Cup fina...      spam
# 3     ham  U dun say so early hor... U c already then say...  Personal
# 4     ham  Nah I don't think he goes to usf, he lives aro...  Personal
# 5    spam  FreeMsg Hey there darling it's been 3 week's n...      spam
# 6     ham  Even my brother is not like to speak with me. ...  Personal
# 7     ham  As per your request 'Melle Melle (Oru Minnamin...  Personal
# 8    spam  WINNER!! As a valued network customer you have...      spam
# 9    spam  Had your mobile 11 months or more? U R entitle...      spam
# 10    ham  I'm gonna be home soon and i don't want to tal...  Personal
# 11   spam  SIX chances to win CASH! From 100 to 20,000 po...      spam
# ...

# %%
A1
# Out:
#                                                   Body    labels
# 0                                Bugis oso near wat...  Personal
# 1    Go until jurong point, crazy.. Available only ...  Personal
# 2       I dunno until when... Lets go learn pilates...  Personal
# 3    Den only weekdays got special price... Haiz......  Personal
# 4                               Meet after lunch la...  Personal
# 5    m walking in citylink now  faster come down......  Personal
# 6    5 nights...We nt staying at port step liao...T...  Personal
# 7    Hey pple...$700 or $900 for 5 nights...Excelle...  Personal
# 8    Yun ah.the ubi one say if  wan call by tomorro...  Personal
# 9                    Hey tmr maybe can meet you at yck  Personal
# 10            Oh...i asked for fun. Haha...take care.   Personal
# 11   We are supposed to meet to discuss abt our tri...  Personal
# 12                             t finish my film yet...  Personal
# ...

# %%
A2.rename(columns={'Labels':'labels','v2':'body'},inplace=True)

# %%
A2
# Out:
#        v1                                               body    labels
# 0     ham  Go until jurong point, crazy.. Available only ...  Personal
# 1     ham                      Ok lar... Joking wif u oni...  Personal
# 2    spam  Free entry in 2 a wkly comp to win FA Cup fina...      spam
# 3     ham  U dun say so early hor... U c already then say...  Personal
# 4     ham  Nah I don't think he goes to usf, he lives aro...  Personal
# 5    spam  FreeMsg Hey there darling it's been 3 week's n...      spam
# 6     ham  Even my brother is not like to speak with me. ...  Personal
# 7     ham  As per your request 'Melle Melle (Oru Minnamin...  Personal
# 8    spam  WINNER!! As a valued network customer you have...      spam
# 9    spam  Had your mobile 11 months or more? U R entitle...      spam
# 10    ham  I'm gonna be home soon and i don't want to tal...  Personal
# 11   spam  SIX chances to win CASH! From 100 to 20,000 po...      spam
# ...

# %%
A1
# Out:
#                                                   Body    labels
# 0                                Bugis oso near wat...  Personal
# 1    Go until jurong point, crazy.. Available only ...  Personal
# 2       I dunno until when... Lets go learn pilates...  Personal
# 3    Den only weekdays got special price... Haiz......  Personal
# 4                               Meet after lunch la...  Personal
# 5    m walking in citylink now  faster come down......  Personal
# 6    5 nights...We nt staying at port step liao...T...  Personal
# 7    Hey pple...$700 or $900 for 5 nights...Excelle...  Personal
# 8    Yun ah.the ubi one say if  wan call by tomorro...  Personal
# 9                    Hey tmr maybe can meet you at yck  Personal
# 10            Oh...i asked for fun. Haha...take care.   Personal
# 11   We are supposed to meet to discuss abt our tri...  Personal
# 12                             t finish my film yet...  Personal
# ...

# %%
A1
# Out:
#                                                   Body    labels
# 0                                Bugis oso near wat...  Personal
# 1    Go until jurong point, crazy.. Available only ...  Personal
# 2       I dunno until when... Lets go learn pilates...  Personal
# 3    Den only weekdays got special price... Haiz......  Personal
# 4                               Meet after lunch la...  Personal
# 5    m walking in citylink now  faster come down......  Personal
# 6    5 nights...We nt staying at port step liao...T...  Personal
# 7    Hey pple...$700 or $900 for 5 nights...Excelle...  Personal
# 8    Yun ah.the ubi one say if  wan call by tomorro...  Personal
# 9                    Hey tmr maybe can meet you at yck  Personal
# 10            Oh...i asked for fun. Haha...take care.   Personal
# 11   We are supposed to meet to discuss abt our tri...  Personal
# 12                             t finish my film yet...  Personal
# ...

# %%
A1=pd.read_csv('File23.csv')

# %%
A1
# Out:
#                                                   Body    labels
# 0                                Bugis oso near wat...  Personal
# 1    Go until jurong point, crazy.. Available only ...  Personal
# 2       I dunno until when... Lets go learn pilates...  Personal
# 3    Den only weekdays got special price... Haiz......  Personal
# 4                               Meet after lunch la...  Personal
# 5    m walking in citylink now  faster come down......  Personal
# 6    5 nights...We nt staying at port step liao...T...  Personal
# 7    Hey pple...$700 or $900 for 5 nights...Excelle...  Personal
# 8    Yun ah.the ubi one say if  wan call by tomorro...  Personal
# 9                    Hey tmr maybe can meet you at yck  Personal
# 10            Oh...i asked for fun. Haha...take care.   Personal
# 11   We are supposed to meet to discuss abt our tri...  Personal
# 12                             t finish my film yet...  Personal
# ...

# %%
A2=pd.read_csv('Tyty.csv')

# %%
A2
# Out:
#        v1                                                 v2    Labels
# 0     ham  Go until jurong point, crazy.. Available only ...  Personal
# 1     ham                      Ok lar... Joking wif u oni...  Personal
# 2    spam  Free entry in 2 a wkly comp to win FA Cup fina...      spam
# 3     ham  U dun say so early hor... U c already then say...  Personal
# 4     ham  Nah I don't think he goes to usf, he lives aro...  Personal
# 5    spam  FreeMsg Hey there darling it's been 3 week's n...      spam
# 6     ham  Even my brother is not like to speak with me. ...  Personal
# 7     ham  As per your request 'Melle Melle (Oru Minnamin...  Personal
# 8    spam  WINNER!! As a valued network customer you have...      spam
# 9    spam  Had your mobile 11 months or more? U R entitle...      spam
# 10    ham  I'm gonna be home soon and i don't want to tal...  Personal
# 11   spam  SIX chances to win CASH! From 100 to 20,000 po...      spam
# ...

# %%
A2.rename(columns={'v2':'Body','Labels':'labels'},inplace=True)

# %%
A2
# Out:
#        v1                                               Body    labels
# 0     ham  Go until jurong point, crazy.. Available only ...  Personal
# 1     ham                      Ok lar... Joking wif u oni...  Personal
# 2    spam  Free entry in 2 a wkly comp to win FA Cup fina...      spam
# 3     ham  U dun say so early hor... U c already then say...  Personal
# 4     ham  Nah I don't think he goes to usf, he lives aro...  Personal
# 5    spam  FreeMsg Hey there darling it's been 3 week's n...      spam
# 6     ham  Even my brother is not like to speak with me. ...  Personal
# 7     ham  As per your request 'Melle Melle (Oru Minnamin...  Personal
# 8    spam  WINNER!! As a valued network customer you have...      spam
# 9    spam  Had your mobile 11 months or more? U R entitle...      spam
# 10    ham  I'm gonna be home soon and i don't want to tal...  Personal
# 11   spam  SIX chances to win CASH! From 100 to 20,000 po...      spam
# ...

# %%
A2.drop('v1',axis=1,inplace=True)

# %%
A2
# Out:
#                                                   Body    labels
# 0    Go until jurong point, crazy.. Available only ...  Personal
# 1                        Ok lar... Joking wif u oni...  Personal
# 2    Free entry in 2 a wkly comp to win FA Cup fina...      spam
# 3    U dun say so early hor... U c already then say...  Personal
# 4    Nah I don't think he goes to usf, he lives aro...  Personal
# 5    FreeMsg Hey there darling it's been 3 week's n...      spam
# 6    Even my brother is not like to speak with me. ...  Personal
# 7    As per your request 'Melle Melle (Oru Minnamin...  Personal
# 8    WINNER!! As a valued network customer you have...      spam
# 9    Had your mobile 11 months or more? U R entitle...      spam
# 10   I'm gonna be home soon and i don't want to tal...  Personal
# 11   SIX chances to win CASH! From 100 to 20,000 po...      spam
# 12   URGENT! You have won a 1 week FREE membership ...      spam
# ...

# %%
XY=[A1,A2]

# %%
XY=pd.concat(XY)

# %%
XY.to_csv('Final11',index=False)

# %%
XY['labels'].value_counts()
# Out:
# Personal    408
# spam         37
# Name: labels, dtype: int64

# %%
ABC=pd.read_csv('finalFile.txt',delimiter='$')

# %%
ABC
# Out:
#                                                  Body    labels
# 0   Dear Customer, You have 4 missed calls from +9...   service
# 1   Dear Customer, You have a missed call from +91...   service
# 2   Mubarak ho! Aapke recharge ho gaya hai. Aap ke...   service
# 3   Dear Customer, You have 2 missed calls from +9...   service
# 4   Aapko mila hai free 50 MB internet pack 7 din ...   service
# 5   Worry FREE Voice & Data usage option for you! ...   service
# 6   Airtel Prepaid Dhamaka! RC351=Unlimited Calls+...   service
# 7   Airtel Prepaid Dhamaka! RC351=Unlimited Calls+...   service
# 8   Dear Customer, You have 2 missed calls from +9...   service
# 9   Dear Customer, You have 3 missed calls from +9...   service
# 10  Dear Customer,  Welcome to Jio-Delhi. For quer...   service
# 11  Dear Customer,  Welcome to Jio-Delhi. For quer...   service
# 12  Dear Customer,  Welcome to Jio-Delhi. For quer...   service
# 13  Dear Customer,  Welcome to Jio-Delhi. For quer...   service
# ...

# %%
ABC['labels'].value_counts()
# Out:
# service     42
# reminder     7
# bank         1
# Name: labels, dtype: int64

# %%
ABC
# Out:
#                                                  Body    labels
# 0   Dear Customer, You have 4 missed calls from +9...   service
# 1   Dear Customer, You have a missed call from +91...   service
# 2   Mubarak ho! Aapke recharge ho gaya hai. Aap ke...   service
# 3   Dear Customer, You have 2 missed calls from +9...   service
# 4   Aapko mila hai free 50 MB internet pack 7 din ...   service
# 5   Worry FREE Voice & Data usage option for you! ...   service
# 6   Airtel Prepaid Dhamaka! RC351=Unlimited Calls+...   service
# 7   Airtel Prepaid Dhamaka! RC351=Unlimited Calls+...   service
# 8   Dear Customer, You have 2 missed calls from +9...   service
# 9   Dear Customer, You have 3 missed calls from +9...   service
# 10  Dear Customer,  Welcome to Jio-Delhi. For quer...   service
# 11  Dear Customer,  Welcome to Jio-Delhi. For quer...   service
# 12  Dear Customer,  Welcome to Jio-Delhi. For quer...   service
# 13  Dear Customer,  Welcome to Jio-Delhi. For quer...   service
# ...

# %%
Lab=[XY,ABC]
XY=pd.concat(Lab)

# %%
XY.to_csv('Final12.csv',index=False)

# %%
A1=pd.read_csv('finalFile1.txt',delimiter='$')

# %%
pd.read_csv('Final11')
# Out:
#                                                   Body    labels
# 0                                Bugis oso near wat...  Personal
# 1    Go until jurong point, crazy.. Available only ...  Personal
# 2       I dunno until when... Lets go learn pilates...  Personal
# 3    Den only weekdays got special price... Haiz......  Personal
# 4                               Meet after lunch la...  Personal
# 5    m walking in citylink now  faster come down......  Personal
# 6    5 nights...We nt staying at port step liao...T...  Personal
# 7    Hey pple...$700 or $900 for 5 nights...Excelle...  Personal
# 8    Yun ah.the ubi one say if  wan call by tomorro...  Personal
# 9                    Hey tmr maybe can meet you at yck  Personal
# 10            Oh...i asked for fun. Haha...take care.   Personal
# 11   We are supposed to meet to discuss abt our tri...  Personal
# 12                             t finish my film yet...  Personal
# ...

# %%
A1['labels'].value_counts()
# Out:
# service    34
# online     29
# bank       20
# cabs       16
# food       10
# others      6
# Name: labels, dtype: int64

# %%
Lab=[XY,A1]
XY=pd.concat(Lab)

# %%
XY['labels'].value_counts()
# Out:
# Personal    408
# service      76
# spam         37
# online       29
# bank         21
# cabs         16
# food         10
# reminder      7
# others        6
# Name: labels, dtype: int64

# %%
XY.to_csv('File14.csv')
