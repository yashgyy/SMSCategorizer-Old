# %%
import numpy as np

# %%
import pandas as pd

# %%
XY=pd.read_csv('File16.csv')

# %%
XY
# Out:
#                                                   Body    labels
# 0                                Bugis oso near wat...  Personal
# 1    Go until jurong point, crazy.. Available only ...  Personal
# 2       I dunno until when... Lets go learn pilates...  Personal
# 3    Den only weekdays got special price... Haiz......  Personal
# 4                               Meet after lunch la...  Personal
# 5    m walking in citylink now  faster come down......  Personal
# 6    5 nights...We nt staying at port step liao...T...  Personal
# 7    Hey pple...$700 or $900 for 5 nights...Excelle...  Personal
# 8    Yun ah.the ubi one say if  wan call by tomorro...  Personal
# 9                    Hey tmr maybe can meet you at yck  Personal
# 10            Oh...i asked for fun. Haha...take care.   Personal
# 11   We are supposed to meet to discuss abt our tri...  Personal
# 12                             t finish my film yet...  Personal
# 13                   m having dinner with my cousin...  Personal
# 14                          Oh... Kay... On sat right?  Personal
# 15                     I need... Coz i never go before  Personal
# 16   s a basic yoga course... at bugis... We can go...  Personal
# 17   I am going to sao mu today. Will be done only ...  Personal
# 18        Hey gals...U all wanna meet 4 dinner at nte?  Personal
# 19                          Jos ask if u wana meet up?  Personal
# 20   Haiyoh... Maybe your hamster was jealous of mi...  Personal
# 21   is your hamster dead? Hey so tmr i meet you at...  Personal
# 22   ve booked the pilates and yoga lesson already....  Personal
# 23   Yup... I havent been there before... You want ...  Personal
# 24   K... Must book a not huh? so going for yoga ba...  Personal
# 25   Hey so this sat are we going for the intro pil...  Personal
# 26                           Sat right? Okay thanks...  Personal
# 27   Yup... From what i remb... I think should be c...  Personal
# 28       m going to get specs. My membership is PX3748  Personal
# 29     We can go 4 e normal pilates after our intro...  Personal
# ..                                                 ...       ...
# 600     Delivered: Reebok REEBOK SPEED Me... with t...    online
# 601     Out for Delivery: Reebok EXCLUSIVE RUNNE......    online
# 602     Delivery Scheduled: Reebok REEBOK SPEED Me....    online
# 603     Your Amazon Prime free trial has ended. Joi...    online
# 604     AirFares@ EaseMyTrip.com -Lowest Price Chal...    others
# 605     Win FREE holiday to Europe, Dubai & Thailan...    others
# 606     Lowest Air-Fare Challenge  Get upto Rs.2000...    others
# 607     www.EaseMyTrip.com : Lowest Fare Challenge....    others
# 608     Goibibo Hot Summer Sale - Upto 70% off + 20...    others
# 609     Dear Yash, Rs 2000.0 is credited to your go...    others
# 610  GENT! We are trying to contact you. Last weeke...      spam
# 611  You are a winner U have been specially selecte...      spam
# 612  PRIVATE! Your 2004 Account Statement for 07742...      spam
# 613  URGENT! Your Mobile No. was awarded 2000 Bonus...      spam
# 614  Todays Voda numbers ending 7548 are selected t...      spam
# 615  Sunshine Quiz Wkly Q! Win a top Sony DVD playe...      spam
# 616  Want 2 get laid tonight? Want real Dogging loc...      spam
# 617  You'll not rcv any more msgs from the chat svc...      spam
# 618  FreeMsg Why haven't you replied to my text? I'...      spam
# 619  Customer service annoncement. You have a New Y...      spam
# 620  You are a winner U have been specially selecte...      spam
# 621  -PLS STOP bootydelious (32/F) is inviting you ...      spam
# 622  BangBabes Ur order is on the way. U SHOULD rec...      spam
# 623  URGENT! We are trying to contact you. Last wee...      spam
# 624  Please call our customer service representativ...      spam
# 625  Are you unique enough? Find out from 30th Augu...      spam
# 626  500 New Mobiles from 2004, MUST GO! Txt: NOKIA...      spam
# 627  Will u meet ur dream partner soon? Is ur caree...      spam
# 628  Text & meet someone sexy today. U can find a d...      spam
# 629  U 447801259231 have a secret admirer who is lo...      spam
#
# [630 rows x 2 columns]

# %%
XY.head()
# Out:
#                                                 Body    labels
# 0                              Bugis oso near wat...  Personal
# 1  Go until jurong point, crazy.. Available only ...  Personal
# 2     I dunno until when... Lets go learn pilates...  Personal
# 3  Den only weekdays got special price... Haiz......  Personal
# 4                             Meet after lunch la...  Personal

# %%
XY['labels'].value_counts()
# Out:
# Personal    408
# service      76
# spam         57
# online       29
# bank         21
# cabs         16
# food         10
# reminder      7
# others        6
# Name: labels, dtype: int64

# %%
XY.describe()  #Exploatary Data Analysis
# Out:
#                                                      Body    labels
# count                                                 630       630
# unique                                                569         9
# top     Dear Customer,  Welcome to Jio-Delhi. For quer...  Personal
# freq                                                   17       408

# %%
XY['len']=XY['Body'].map(len)

# %%
XY
# Out:
#                                                   Body    labels  len
# 0                                Bugis oso near wat...  Personal   21
# 1    Go until jurong point, crazy.. Available only ...  Personal  111
# 2       I dunno until when... Lets go learn pilates...  Personal   46
# 3    Den only weekdays got special price... Haiz......  Personal  140
# 4                               Meet after lunch la...  Personal   22
# 5    m walking in citylink now  faster come down......  Personal   64
# 6    5 nights...We nt staying at port step liao...T...  Personal   51
# 7    Hey pple...$700 or $900 for 5 nights...Excelle...  Personal   81
# 8    Yun ah.the ubi one say if  wan call by tomorro...  Personal  159
# 9                    Hey tmr maybe can meet you at yck  Personal   33
# 10            Oh...i asked for fun. Haha...take care.   Personal   40
# 11   We are supposed to meet to discuss abt our tri...  Personal  132
# 12                             t finish my film yet...  Personal   23
# 13                   m having dinner with my cousin...  Personal   33
# 14                          Oh... Kay... On sat right?  Personal   26
# 15                     I need... Coz i never go before  Personal   31
# 16   s a basic yoga course... at bugis... We can go...  Personal  114
# 17   I am going to sao mu today. Will be done only ...  Personal   51
# 18        Hey gals...U all wanna meet 4 dinner at nte?  Personal   44
# 19                          Jos ask if u wana meet up?  Personal   26
# 20   Haiyoh... Maybe your hamster was jealous of mi...  Personal   51
# 21   is your hamster dead? Hey so tmr i meet you at...  Personal   63
# 22   ve booked the pilates and yoga lesson already....  Personal   53
# 23   Yup... I havent been there before... You want ...  Personal   87
# 24   K... Must book a not huh? so going for yoga ba...  Personal   60
# 25   Hey so this sat are we going for the intro pil...  Personal   79
# 26                           Sat right? Okay thanks...  Personal   25
# 27   Yup... From what i remb... I think should be c...  Personal   56
# 28       m going to get specs. My membership is PX3748  Personal   45
# 29     We can go 4 e normal pilates after our intro...  Personal   47
# ..                                                 ...       ...  ...
# 600     Delivered: Reebok REEBOK SPEED Me... with t...    online  163
# 601     Out for Delivery: Reebok EXCLUSIVE RUNNE......    online  198
# 602     Delivery Scheduled: Reebok REEBOK SPEED Me....    online  229
# 603     Your Amazon Prime free trial has ended. Joi...    online  147
# 604     AirFares@ EaseMyTrip.com -Lowest Price Chal...    others  164
# 605     Win FREE holiday to Europe, Dubai & Thailan...    others  159
# 606     Lowest Air-Fare Challenge  Get upto Rs.2000...    others  164
# 607     www.EaseMyTrip.com : Lowest Fare Challenge....    others  164
# 608     Goibibo Hot Summer Sale - Upto 70% off + 20...    others  133
# 609     Dear Yash, Rs 2000.0 is credited to your go...    others  172
# 610  GENT! We are trying to contact you. Last weeke...      spam  157
# 611  You are a winner U have been specially selecte...      spam  151
# 612  PRIVATE! Your 2004 Account Statement for 07742...      spam  144
# 613  URGENT! Your Mobile No. was awarded 2000 Bonus...      spam  155
# 614  Todays Voda numbers ending 7548 are selected t...      spam  156
# 615  Sunshine Quiz Wkly Q! Win a top Sony DVD playe...      spam  125
# 616  Want 2 get laid tonight? Want real Dogging loc...      spam  162
# 617  You'll not rcv any more msgs from the chat svc...      spam  155
# 618  FreeMsg Why haven't you replied to my text? I'...      spam  159
# 619  Customer service annoncement. You have a New Y...      spam  124
# 620  You are a winner U have been specially selecte...      spam  144
# 621  -PLS STOP bootydelious (32/F) is inviting you ...      spam  152
# 622  BangBabes Ur order is on the way. U SHOULD rec...      spam  155
# 623  URGENT! We are trying to contact you. Last wee...      spam  155
# 624  Please call our customer service representativ...      spam  147
# 625  Are you unique enough? Find out from 30th Augu...      spam   72
# 626  500 New Mobiles from 2004, MUST GO! Txt: NOKIA...      spam  142
# 627  Will u meet ur dream partner soon? Is ur caree...      spam  137
# 628  Text & meet someone sexy today. U can find a d...      spam  157
# 629  U 447801259231 have a secret admirer who is lo...      spam  145
#
# [630 rows x 3 columns]

# %% [markdown]
# #### Following Function Removes Punctuation in String ####

# %%
import string
def Remove_Punctuation(String):
    char1=''
    for X in String:
        if X in string.punctuation:
            char1+=" "
        else:
            char1+=X
    return char1

            
#Function to Remove Punctuation

# %%
XY['BODY1']=XY['Body'].apply(Remove_Punctuation)

# %%
XY['BODY1']
# Out:
# 0                                  Bugis oso near wat
# 1      Go until jurong point  crazy   Available only ...
# 2         I dunno until when    Lets go learn pilates
# 3      Den only weekdays got special price    Haiz   ...
# 4                                 Meet after lunch la
# 5      m walking in citylink now  faster come down   ...
# 6      5 nights   We nt staying at port step liao   T...
# 7      Hey pple    700 or  900 for 5 nights   Excelle...
# 8      Yun ah the ubi one say if  wan call by tomorro...
# 9                      Hey tmr maybe can meet you at yck
# 10              Oh   i asked for fun  Haha   take care
# 11     We are supposed to meet to discuss abt our tri...
# 12                               t finish my film yet
# 13                     m having dinner with my cousin
# 14                            Oh    Kay    On sat right
# 15                       I need    Coz i never go before
# 16     s a basic yoga course    at bugis    We can go...
# 17     I am going to sao mu today  Will be done only ...
# 18          Hey gals   U all wanna meet 4 dinner at nte
# 19                            Jos ask if u wana meet up
# 20     Haiyoh    Maybe your hamster was jealous of mi...
# 21     is your hamster dead  Hey so tmr i meet you at...
# 22     ve booked the pilates and yoga lesson already ...
# 23     Yup    I havent been there before    You want ...
# 24     K    Must book a not huh  so going for yoga ba...
# 25     Hey so this sat are we going for the intro pil...
# 26                             Sat right  Okay thanks
# 27     Yup    From what i remb    I think should be c...
# 28         m going to get specs  My membership is PX3748
# 29       We can go 4 e normal pilates after our intro
#                              ...
# 600       Delivered  Reebok REEBOK SPEED Me    with t...
# 601       Out for Delivery  Reebok EXCLUSIVE RUNNE   ...
# 602       Delivery Scheduled  Reebok REEBOK SPEED Me ...
# 603       Your Amazon Prime free trial has ended  Joi...
# 604       AirFares  EaseMyTrip com  Lowest Price Chal...
# 605       Win FREE holiday to Europe  Dubai   Thailan...
# 606       Lowest Air Fare Challenge  Get upto Rs 2000...
# 607       www EaseMyTrip com   Lowest Fare Challenge ...
# 608       Goibibo Hot Summer Sale   Upto 70  off   20...
# 609       Dear Yash  Rs 2000 0 is credited to your go...
# 610    GENT  We are trying to contact you  Last weeke...
# 611    You are a winner U have been specially selecte...
# 612    PRIVATE  Your 2004 Account Statement for 07742...
# 613    URGENT  Your Mobile No  was awarded 2000 Bonus...
# 614    Todays Voda numbers ending 7548 are selected t...
# 615    Sunshine Quiz Wkly Q  Win a top Sony DVD playe...
# 616    Want 2 get laid tonight  Want real Dogging loc...
# 617    You ll not rcv any more msgs from the chat svc...
# 618    FreeMsg Why haven t you replied to my text  I ...
# 619    Customer service annoncement  You have a New Y...
# 620    You are a winner U have been specially selecte...
# 621     PLS STOP bootydelious  32 F  is inviting you ...
# 622    BangBabes Ur order is on the way  U SHOULD rec...
# 623    URGENT  We are trying to contact you  Last wee...
# 624    Please call our customer service representativ...
# 625    Are you unique enough  Find out from 30th Augu...
# 626    500 New Mobiles from 2004  MUST GO  Txt  NOKIA...
# 627    Will u meet ur dream partner soon  Is ur caree...
# 628    Text   meet someone sexy today  U can find a d...
# 629    U 447801259231 have a secret admirer who is lo...
# Name: BODY1, Length: 630, dtype: object

# %% [markdown]
# #### StopWords are Need to Be Removed for Proper Function ####

# %% [markdown]
# ####  StopWords are common English Alphabets in String

# %%
from nltk.corpus import stopwords
def Remove_Punctuation1(String):
    Mess=stopwords.words('english')
    List1=String.split()
    List2=list()
    for X in List1:
        if X in Mess:
            pass
        else:
            List2.append(X)
    return ' '.join(List2)

# %%
XY['Body2']=XY['BODY1'].map(Remove_Punctuation1) 

# The Function Map will Pass every String of the Column and return the Function
    # to pass the newly Formed String

# %%
XY
# Out:
#                                                   Body    labels  len  \
# 0                                Bugis oso near wat...  Personal   21
# 1    Go until jurong point, crazy.. Available only ...  Personal  111
# 2       I dunno until when... Lets go learn pilates...  Personal   46
# 3    Den only weekdays got special price... Haiz......  Personal  140
# 4                               Meet after lunch la...  Personal   22
# 5    m walking in citylink now  faster come down......  Personal   64
# 6    5 nights...We nt staying at port step liao...T...  Personal   51
# 7    Hey pple...$700 or $900 for 5 nights...Excelle...  Personal   81
# 8    Yun ah.the ubi one say if  wan call by tomorro...  Personal  159
# 9                    Hey tmr maybe can meet you at yck  Personal   33
# 10            Oh...i asked for fun. Haha...take care.   Personal   40
# 11   We are supposed to meet to discuss abt our tri...  Personal  132
# 12                             t finish my film yet...  Personal   23
# 13                   m having dinner with my cousin...  Personal   33
# 14                          Oh... Kay... On sat right?  Personal   26
# 15                     I need... Coz i never go before  Personal   31
# 16   s a basic yoga course... at bugis... We can go...  Personal  114
# 17   I am going to sao mu today. Will be done only ...  Personal   51
# 18        Hey gals...U all wanna meet 4 dinner at nte?  Personal   44
# 19                          Jos ask if u wana meet up?  Personal   26
# 20   Haiyoh... Maybe your hamster was jealous of mi...  Personal   51
# 21   is your hamster dead? Hey so tmr i meet you at...  Personal   63
# 22   ve booked the pilates and yoga lesson already....  Personal   53
# 23   Yup... I havent been there before... You want ...  Personal   87
# 24   K... Must book a not huh? so going for yoga ba...  Personal   60
# 25   Hey so this sat are we going for the intro pil...  Personal   79
# 26                           Sat right? Okay thanks...  Personal   25
# 27   Yup... From what i remb... I think should be c...  Personal   56
# 28       m going to get specs. My membership is PX3748  Personal   45
# 29     We can go 4 e normal pilates after our intro...  Personal   47
# ..                                                 ...       ...  ...
# 600     Delivered: Reebok REEBOK SPEED Me... with t...    online  163
# 601     Out for Delivery: Reebok EXCLUSIVE RUNNE......    online  198
# 602     Delivery Scheduled: Reebok REEBOK SPEED Me....    online  229
# 603     Your Amazon Prime free trial has ended. Joi...    online  147
# 604     AirFares@ EaseMyTrip.com -Lowest Price Chal...    others  164
# 605     Win FREE holiday to Europe, Dubai & Thailan...    others  159
# 606     Lowest Air-Fare Challenge  Get upto Rs.2000...    others  164
# 607     www.EaseMyTrip.com : Lowest Fare Challenge....    others  164
# 608     Goibibo Hot Summer Sale - Upto 70% off + 20...    others  133
# 609     Dear Yash, Rs 2000.0 is credited to your go...    others  172
# 610  GENT! We are trying to contact you. Last weeke...      spam  157
# 611  You are a winner U have been specially selecte...      spam  151
# 612  PRIVATE! Your 2004 Account Statement for 07742...      spam  144
# 613  URGENT! Your Mobile No. was awarded 2000 Bonus...      spam  155
# 614  Todays Voda numbers ending 7548 are selected t...      spam  156
# 615  Sunshine Quiz Wkly Q! Win a top Sony DVD playe...      spam  125
# 616  Want 2 get laid tonight? Want real Dogging loc...      spam  162
# 617  You'll not rcv any more msgs from the chat svc...      spam  155
# 618  FreeMsg Why haven't you replied to my text? I'...      spam  159
# 619  Customer service annoncement. You have a New Y...      spam  124
# 620  You are a winner U have been specially selecte...      spam  144
# 621  -PLS STOP bootydelious (32/F) is inviting you ...      spam  152
# 622  BangBabes Ur order is on the way. U SHOULD rec...      spam  155
# 623  URGENT! We are trying to contact you. Last wee...      spam  155
# 624  Please call our customer service representativ...      spam  147
# 625  Are you unique enough? Find out from 30th Augu...      spam   72
# 626  500 New Mobiles from 2004, MUST GO! Txt: NOKIA...      spam  142
# 627  Will u meet ur dream partner soon? Is ur caree...      spam  137
# 628  Text & meet someone sexy today. U can find a d...      spam  157
# 629  U 447801259231 have a secret admirer who is lo...      spam  145
#
#                                                  BODY1  \
# 0                                Bugis oso near wat
# 1    Go until jurong point  crazy   Available only ...
# 2       I dunno until when    Lets go learn pilates
# 3    Den only weekdays got special price    Haiz   ...
# 4                               Meet after lunch la
# 5    m walking in citylink now  faster come down   ...
# 6    5 nights   We nt staying at port step liao   T...
# 7    Hey pple    700 or  900 for 5 nights   Excelle...
# 8    Yun ah the ubi one say if  wan call by tomorro...
# 9                    Hey tmr maybe can meet you at yck
# 10            Oh   i asked for fun  Haha   take care
# 11   We are supposed to meet to discuss abt our tri...
# 12                             t finish my film yet
# 13                   m having dinner with my cousin
# 14                          Oh    Kay    On sat right
# 15                     I need    Coz i never go before
# 16   s a basic yoga course    at bugis    We can go...
# 17   I am going to sao mu today  Will be done only ...
# 18        Hey gals   U all wanna meet 4 dinner at nte
# 19                          Jos ask if u wana meet up
# 20   Haiyoh    Maybe your hamster was jealous of mi...
# 21   is your hamster dead  Hey so tmr i meet you at...
# 22   ve booked the pilates and yoga lesson already ...
# 23   Yup    I havent been there before    You want ...
# 24   K    Must book a not huh  so going for yoga ba...
# 25   Hey so this sat are we going for the intro pil...
# 26                           Sat right  Okay thanks
# 27   Yup    From what i remb    I think should be c...
# 28       m going to get specs  My membership is PX3748
# 29     We can go 4 e normal pilates after our intro
# ..                                                 ...
# 600     Delivered  Reebok REEBOK SPEED Me    with t...
# 601     Out for Delivery  Reebok EXCLUSIVE RUNNE   ...
# 602     Delivery Scheduled  Reebok REEBOK SPEED Me ...
# 603     Your Amazon Prime free trial has ended  Joi...
# 604     AirFares  EaseMyTrip com  Lowest Price Chal...
# 605     Win FREE holiday to Europe  Dubai   Thailan...
# 606     Lowest Air Fare Challenge  Get upto Rs 2000...
# 607     www EaseMyTrip com   Lowest Fare Challenge ...
# 608     Goibibo Hot Summer Sale   Upto 70  off   20...
# 609     Dear Yash  Rs 2000 0 is credited to your go...
# 610  GENT  We are trying to contact you  Last weeke...
# 611  You are a winner U have been specially selecte...
# 612  PRIVATE  Your 2004 Account Statement for 07742...
# 613  URGENT  Your Mobile No  was awarded 2000 Bonus...
# 614  Todays Voda numbers ending 7548 are selected t...
# 615  Sunshine Quiz Wkly Q  Win a top Sony DVD playe...
# 616  Want 2 get laid tonight  Want real Dogging loc...
# 617  You ll not rcv any more msgs from the chat svc...
# 618  FreeMsg Why haven t you replied to my text  I ...
# 619  Customer service annoncement  You have a New Y...
# 620  You are a winner U have been specially selecte...
# 621   PLS STOP bootydelious  32 F  is inviting you ...
# 622  BangBabes Ur order is on the way  U SHOULD rec...
# 623  URGENT  We are trying to contact you  Last wee...
# 624  Please call our customer service representativ...
# 625  Are you unique enough  Find out from 30th Augu...
# 626  500 New Mobiles from 2004  MUST GO  Txt  NOKIA...
# 627  Will u meet ur dream partner soon  Is ur caree...
# 628  Text   meet someone sexy today  U can find a d...
# 629  U 447801259231 have a secret admirer who is lo...
#
#                                                  Body2
# 0                                   Bugis oso near wat
# 1    Go jurong point crazy Available bugis n great ...
# 2                        I dunno Lets go learn pilates
# 3    Den weekdays got special price Haiz Cant eat l...
# 4                                        Meet lunch la
# 5               walking citylink faster come Me hungry
# 6         5 nights We nt staying port step liao Too ex
# 7    Hey pple 700 900 5 nights Excellent location w...
# 8    Yun ah ubi one say wan call tomorrow call 6744...
# 9                               Hey tmr maybe meet yck
# 10                         Oh asked fun Haha take care
# 11   We supposed meet discuss abt trip Thought xuhu...
# 12                                     finish film yet
# 13                                       dinner cousin
# 14                                 Oh Kay On sat right
# 15                                 I need Coz never go
# 16   basic yoga course bugis We go Pilates intro ne...
# 17                   I going sao mu today Will done 12
# 18                  Hey gals U wanna meet 4 dinner nte
# 19                                 Jos ask u wana meet
# 20                Haiyoh Maybe hamster jealous million
# 21           hamster dead Hey tmr meet 1pm orchard mrt
# 22             booked pilates yoga lesson already Haha
# 23           Yup I havent You want go yoga I call book
# 24             K Must book huh going yoga basic sunday
# 25           Hey sat going intro pilates Or kickboxing
# 26                               Sat right Okay thanks
# 27                          Yup From remb I think book
# 28                going get specs My membership PX3748
# 29                      We go 4 e normal pilates intro
# ..                                                 ...
# 600  Delivered Reebok REEBOK SPEED Me tracking ID F...
# 601  Out Delivery Reebok EXCLUSIVE RUNNE tracking I...
# 602  Delivery Scheduled Reebok REEBOK SPEED Me trac...
# 603  Your Amazon Prime free trial ended Join today ...
# 604  AirFares EaseMyTrip com Lowest Price Challenge...
# 605  Win FREE holiday Europe Dubai Thailand Use Cod...
# 606  Lowest Air Fare Challenge Get upto Rs 2000 OFF...
# 607  www EaseMyTrip com Lowest Fare Challenge Use C...
# 608  Goibibo Hot Summer Sale Upto 70 20 goCash usag...
# 609  Dear Yash Rs 2000 0 credited goCash c Your Net...
# 610  GENT We trying contact Last weekends draw show...
# 611  You winner U specially selected 2 receive 1000...
# 612  PRIVATE Your 2004 Account Statement 0774267696...
# 613  URGENT Your Mobile No awarded 2000 Bonus Calle...
# 614  Todays Voda numbers ending 7548 selected recei...
# 615  Sunshine Quiz Wkly Q Win top Sony DVD player u...
# 616  Want 2 get laid tonight Want real Dogging loca...
# 617  You rcv msgs chat svc For FREE Hardcore servic...
# 618  FreeMsg Why replied text I Randy sexy female l...
# 619  Customer service annoncement You New Years del...
# 620  You winner U specially selected 2 receive 1000...
# 621  PLS STOP bootydelious 32 F inviting friend Rep...
# 622  BangBabes Ur order way U SHOULD receive Servic...
# 623  URGENT We trying contact Last weekends draw sh...
# 624  Please call customer service representative FR...
# 625  Are unique enough Find 30th August www areyouu...
# 626  500 New Mobiles 2004 MUST GO Txt NOKIA No 8954...
# 627  Will u meet ur dream partner soon Is ur career...
# 628  Text meet someone sexy today U find date even ...
# 629  U 447801259231 secret admirer looking 2 make c...
#
# [630 rows x 5 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# #### Count Vectoriser Object Will Form the Dictionary of the Unique Object

# %%
bow_Transformer=CountVectorizer().fit(XY['Body2'])

# %%
print(len(bow_Transformer.vocabulary_))
# Out:
# 2334

# %% [markdown]
# #### There are 2334 Unique Words In the Dataset

# %%
#For example

bow_Transformer.get_feature_names()[1001]
# Out:
# 'had'

# %%
message_bow=bow_Transformer.transform(XY['Body2'])

# %% [markdown]
# #### TFIDF
#
# * Tf-Idf will Consist of Two terms in Particular and weigh down Term Inverse Document Frequency . Here the TF refers to
#
#     * TF, which measures how frequently a term occurs in a document. Since every document is different in length, it is possible that a term would appear much more times in long documents than shorter ones.
#
#     * IDF which measures how important a term is. While computing TF, all terms are considered equally important. However it is known that certain terms, such as "is", "of", and "that", may appear a lot of times but have little importance
#
# ** IDF(t) = log_e(Total number of documents / Number of documents with term t in it) **

# %%
from sklearn.feature_extraction.text import TfidfTransformer

tfidf_transformer=TfidfTransformer().fit(message_bow)
tfidf4=tfidf_transformer.fit(message_bow)

# %%
## Example of Tf Idf Transformer

message_FINAL=tfidf_transformer.transform(message_bow)

# %%
message_FINAL.shape
# Out:
# (630, 2334)

# %% [markdown]
# #### For Training the Model We will Use Random Forest Classification which has the added Method of Ensemble

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# Here We are Traning ON TO THE WHOLE CATEGORY TO MEASURE THE ROBUTNESS
X=RandomForestClassifier()
X.fit(message_FINAL,XY['labels'])
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
Predict=X.predict(message_FINAL)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(XY['labels'],Predict))


# Classifying to the Report Well
# Out:
#              precision    recall  f1-score   support
#
#    Personal       0.99      1.00      1.00       408
#        bank       0.88      1.00      0.93        21
#        cabs       1.00      1.00      1.00        16
#        food       0.91      1.00      0.95        10
#      online       1.00      0.86      0.93        29
#      others       1.00      1.00      1.00         6
#    reminder       1.00      0.86      0.92         7
#     service       1.00      1.00      1.00        76
#        spam       1.00      0.96      0.98        57
#
# avg / total       0.99      0.99      0.99       630

# %%
from sklearn.model_selection import train_test_split

# %%
msg_train, msg_test, label_train, label_test=train_test_split(XY['BODY1'],XY['labels'],test_size=0.2)

# %% [markdown]
# #### Same process Will be Followed For above Msg train

# %%
msg_train
# Out:
# 200                            m on da bus going home
# 426    Would really appreciate if you call me  Just n...
# 241    Pls go ahead with watts  I just wanted to be s...
# 7      Hey pple    700 or  900 for 5 nights   Excelle...
# 276          I am waiting machan  Call me once you free
# 105                      K  Did you call me just now ah
# 134                            still attending da talks
# 83     Hey you still want to go for yogasana  Coz if ...
# 385                           Going on nothing great bye
# 161                                                Ok
# 246                     No calls  messages  missed calls
# 108                                      You want to go
# 348    Ummma will call after check in our life will b...
# 598       Congratulations  Your wallet has been rewar...
# 194      When  login dat time    Dad fetching  home now
# 340    Got c    I lazy to type    I forgot   in lect ...
# 469    Dear Customer   Welcome to Jio Delhi  For quer...
# 43     Aiyo    U always c our ex one    I dunno abt m...
# 346     Whats the staff name who is taking class for us
# 621     PLS STOP bootydelious  32 F  is inviting you ...
# 582       Your unutilized cashback of Rs  200 of Augu...
# 411    What s up bruv  hope you had a great break  Do...
# 501       This year  don t just watch Jio Kaun Banega...
# 611    You are a winner U have been specially selecte...
# 26                             Sat right  Okay thanks
# 594       Thank you for choosing MTicket as your book...
# 185            Black shirt n blue jeans    I thk i c
# 307          Aight  I ll hit you up when I get some cash
# 329    HEY GIRL  HOW R U  HOPE U R WELL ME AN DEL R B...
# 57                           Hey tmr meet at bugis 930
#                              ...
# 314    GENT  We are trying to contact you  Last weeke...
# 542       Dear Customer  State Bank of India wishes y...
# 562       Your coupon worth Rs  50 on your first ride...
# 281                               Sorry  I ll call later
# 399    Hi its Kate how is your evening  I hope i can ...
# 179                         Mum ask  to buy food home
# 455    Dear Customer   Welcome to Jio Delhi  For quer...
# 123     Huh  6 also cannot  Then only how many mistakes
# 267    Today is  song dedicated day     Which song wi...
# 506       Recharge of Rs  399 is successful for your ...
# 629    U 447801259231 have a secret admirer who is lo...
# 623    URGENT  We are trying to contact you  Last wee...
# 193    How i noe    Did  specify da domain as nusstu ...
# 272                        Finished class where are you
# 125    Hey   Something came up last min   Think i wun...
# 431    Get down in gandhipuram and walk to cross cut ...
# 311             What is the plural of the noun research
# 583       Exclusive Preview of 3 Days FREE SHOPPING a...
# 521       Beware of fraudulent Chat  SMS   email mess...
# 452    Airtel Prepaid Dhamaka  RC351 Unlimited Calls ...
# 13                     m having dinner with my cousin
# 251    What you thinked about me  First time you saw ...
# 305         Umma my life and vava umma love you lot dear
# 182    m askin if  leaving earlier or wat mah cos may...
# 607       www EaseMyTrip com   Lowest Fare Challenge ...
# 90     I only work from mon to thurs but Sat i cant l...
# 547       Go cashless  Dial 14444 toll free for help ...
# 434     Yes  here tv is always available in work place
# 508       Dear Customer  You have 2 missed calls from...
# 515       Apne issi number ko Idea mai portin karke p...
# Name: BODY1, Length: 504, dtype: object

# %%
msg_train1=msg_train.map(Remove_Punctuation)

# %%
msg_train2=msg_train1.map(Remove_Punctuation1)

# %%
msg_train2
# Out:
# 200                                    da bus going home
# 426    Would really appreciate call Just need someone...
# 241    Pls go ahead watts I wanted sure Do great week...
# 7      Hey pple 700 900 5 nights Excellent location w...
# 276                           I waiting machan Call free
# 105                                        K Did call ah
# 134                             still attending da talks
# 83     Hey still want go yogasana Coz end cine go bat...
# 385                              Going nothing great bye
# 161                                                   Ok
# 246                       No calls messages missed calls
# 108                                          You want go
# 348      Ummma call check life begin qatar pls pray hard
# 598    Congratulations Your wallet rewarded Rs 100 00...
# 194                When login dat time Dad fetching home
# 340    Got c I lazy type I forgot lect I saw pouch li...
# 469    Dear Customer Welcome Jio Delhi For queries su...
# 43     Aiyo U always c ex one I dunno abt mei reply F...
# 346                     Whats staff name taking class us
# 621    PLS STOP bootydelious 32 F inviting friend Rep...
# 582    Your unutilized cashback Rs 200 August expired...
# 411     What bruv hope great break Do rewarding semester
# 501    This year watch Jio Kaun Banega Crorepati KBC ...
# 611    You winner U specially selected 2 receive 1000...
# 26                                 Sat right Okay thanks
# 594    Thank choosing MTicket booking option BookMySh...
# 185                     Black shirt n blue jeans I thk c
# 307                               Aight I hit I get cash
# 329    HEY GIRL HOW R U HOPE U R WELL ME AN DEL R BAK...
# 57                                Hey tmr meet bugis 930
#                              ...
# 314    GENT We trying contact Last weekends draw show...
# 542    Dear Customer State Bank India wishes Very Hap...
# 562    Your coupon worth Rs 50 first ride awaits Open...
# 281                                   Sorry I call later
# 399    Hi Kate evening I hope see tomorrow bit bloody...
# 179                                Mum ask buy food home
# 455    Dear Customer Welcome Jio Delhi For queries su...
# 123                 Huh 6 also cannot Then many mistakes
# 267    Today song dedicated day Which song u dedicate...
# 506    Recharge Rs 399 successful Jio number 82799259...
# 629    U 447801259231 secret admirer looking 2 make c...
# 623    URGENT We trying contact Last weekends draw sh...
# 193       How noe Did specify da domain nusstu still sch
# 272                                       Finished class
# 125    Hey Something came last min Think wun signing ...
# 431    Get gandhipuram walk cross cut road Right side...
# 311                            What plural noun research
# 583    Exclusive Preview 3 Days FREE SHOPPING CENTRAL...
# 521    Beware fraudulent Chat SMS email messages aski...
# 452    Airtel Prepaid Dhamaka RC351 Unlimited Calls D...
# 13                                         dinner cousin
# 251                    What thinked First time saw class
# 305                    Umma life vava umma love lot dear
# 182    askin leaving earlier wat mah cos mayb haf wal...
# 607    www EaseMyTrip com Lowest Fare Challenge Use C...
# 90     I work mon thurs Sat cant leh Booked liao Whic...
# 547    Go cashless Dial 14444 toll free help digital ...
# 434                   Yes tv always available work place
# 508    Dear Customer You 2 missed calls 919654374617 ...
# 515    Apne issi number ko Idea mai portin karke paye...
# Name: BODY1, Length: 504, dtype: object

# %%
#Count Vectoriser Object

# %%
XX=CountVectorizer()

# %%
Final_Message=XX.fit_transform(msg_train2)

# %%
XXX=TfidfTransformer()

# %%
Final_Message=XXX.fit_transform(Final_Message)

# %%
X.fit(Final_Message,label_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
def text_process(mess):
    """
    Takes in a string of text, then performs the following:
    1. Remove all punctuation
    2. Remove all stopwords
    3. Returns a list of the cleaned text
    """
    # Check characters to see if they are in punctuation
    nopunc = [char for char in mess if char not in string.punctuation]

    # Join the characters again to form the string.
    nopunc = ''.join(nopunc)
    
    # Now just remove any stopwords
    return [word for word in nopunc.split() if word.lower() not in stopwords.words('english')]

# %% [markdown]
# #### Here WE Need A Pipeline BECAUSE every message Need To go Through This Whole Process OF Vectorising, Transforming and Classification Thats WHy pipeline iS Essential

# %%
from sklearn.pipeline import Pipeline

pipeline = Pipeline([
    ('bow', CountVectorizer(analyzer=text_process)),  # strings to token integer counts
    ('tfidf', TfidfTransformer()),  # integer counts to weighted TF-IDF scores
    ('classifier', RandomForestClassifier()),  # train on TF-IDF vectors w/ Naive Bayes classifier
])

# %%
pipeline.fit(msg_train,label_train)
# Out:
# Pipeline(memory=None,
#      steps=[('bow', CountVectorizer(analyzer=<function text_process at 0x000002E5BC15DEA0>,
#         binary=False, decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=1, ngram_range=(1, 1), preprocesso...n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False))])

# %%
print(classification_report(predictions,label_test))
# Out:
#              precision    recall  f1-score   support
#
#    Personal       1.00      0.84      0.91       102
#        bank       1.00      0.67      0.80         3
#        cabs       0.50      1.00      0.67         1
#        food       0.33      1.00      0.50         1
#      online       0.60      1.00      0.75         3
#      others       0.00      0.00      0.00         0
#    reminder       0.00      0.00      0.00         0
#     service       0.79      0.92      0.85        12
#        spam       0.33      1.00      0.50         4
#
# avg / total       0.94      0.86      0.88       126
# C:\Users\yashg\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1137: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
from sklearn.externals import joblib

# %% [markdown]
# ### The Following Files Will Save the Whole Model involving all the Language Processing like (Vectorising StopWords) and Final Classification Machine Learning Model all in One File

# %%
joblib.dump(pipeline,"NLTK[RANDOMFOREST].pkl")
# Out:
# ['NLTK[RANDOMFOREST].pkl']

# %%
classifier=joblib.load('Model1.pkl')

# %%
classifier.predict(["Hello"])
# Out:
# array(['Personal'], dtype=object)
